# %% [markdown]
# <center><p>
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/4_RGB_McCombs_School_Brand_Branded.png" alt="No description has been provided for this image"></img>
# <img src="https://mma.prnewswire.com/media/1458111/Great_Learning_Logo.jpg?p=facebook" alt="No description has been provided for this image"></img>
# </p></center>
# <center><font>Artificial Intelligence and Machine Learning</font></center>
# <center><font>Ensemble Techniques and Model Tuning</font></center>

# %% [markdown]
# <center><img src="https://images.pexels.com/photos/7235894/pexels-photo-7235894.jpeg?auto=compress&amp;cs=tinysrgb&amp;w=1260&amp;h=750&amp;dpr=2" alt="No description has been provided for this image"></img></center>
# <center><font>Visa Approval Facilitation</font></center>

# %% [markdown]
# <h1><strong>Problem Statement</strong></h1>

# %% [markdown]
# <h2>Context</h2>

# %% [markdown]
# <p>Business communities in the United States are facing high demand for human resources, but one of the constant challenges is identifying and attracting the right talent, which is perhaps the most important element in remaining competitive. Companies in the United States look for hard-working, talented, and qualified individuals both locally as well as abroad.</p>
# <p>The Immigration and Nationality Act (INA) of the US permits foreign workers to come to the United States to work on either a temporary or permanent basis. The act also protects US workers against adverse impacts on their wages or working conditions by ensuring US employers' compliance with statutory requirements when they hire foreign workers to fill workforce shortages. The immigration programs are administered by the Office of Foreign Labor Certification (OFLC).</p>
# <p>OFLC processes job certification applications for employers seeking to bring foreign workers into the United States and grants certifications in those cases where employers can demonstrate that there are not sufficient US workers available to perform the work at wages that meet or exceed the wage paid for the occupation in the area of intended employment.</p>

# %% [markdown]
# <h2>Objective</h2>

# %% [markdown]
# <p>In FY 2016, the OFLC processed 775,979 employer applications for 1,699,957 positions for temporary and permanent labor certifications. This was a nine percent increase in the overall number of processed applications from the previous year. The process of reviewing every case is becoming a tedious task as the number of applicants is increasing every year.</p>
# <p>The increasing number of applicants every year calls for a Machine Learning based solution that can help in shortlisting the candidates having higher chances of VISA approval. OFLC has hired the firm EasyVisa for data-driven solutions. You as a data  scientist at EasyVisa have to analyze the data provided and, with the help of a classification model:</p>
# <ul>
# <li>Facilitate the process of visa approvals.</li>
# <li>Recommend a suitable profile for the applicants for whom the visa should be certified or denied based on the drivers that significantly influence the case status.</li>
# </ul>

# %% [markdown]
# <h2>Data Description</h2>

# %% [markdown]
# <p>The data contains the different attributes of employee and the employer. The detailed data dictionary is given below.</p>
# <ul>
# <li>case_id: ID of each visa application</li>
# <li>continent: Information of continent the employee</li>
# <li>education_of_employee: Information of education of the employee</li>
# <li>has_job_experience: Does the employee has any job experience? Y= Yes; N = No</li>
# <li>requires_job_training: Does the employee require any job training? Y = Yes; N = No</li>
# <li>no_of_employees: Number of employees in the employer's company</li>
# <li>yr_of_estab: Year in which the employer's company was established</li>
# <li>region_of_employment: Information of foreign worker's intended region of employment in the US.</li>
# <li>prevailing_wage:  Average wage paid to similarly employed workers in a specific occupation in the area of intended employment. The purpose of the prevailing wage is to ensure that the foreign worker is not underpaid compared to other workers offering the same or similar service in the same area of employment.</li>
# <li>unit_of_wage: Unit of prevailing wage. Values include Hourly, Weekly, Monthly, and Yearly.</li>
# <li>full_time_position: Is the position of work full-time? Y = Full Time Position; N = Part Time Position</li>
# <li>case_status:  Flag indicating if the Visa was certified or denied</li>
# </ul>

# %% [markdown]
# <h2>Note: This is a sample solution for the project. Projects will NOT be graded on the basis of how well the submission matches this sample solution. Projects will be graded on the basis of the rubric only.</h2>

# %% [markdown]
# <h1><strong>Importing necessary libraries</strong></h1>

# %%
# Installing the libraries with the specified version.
# !pip install numpy==2.0.2 pandas==2.2.2 scikit-learn==1.6.1 matplotlib==3.10.0 seaborn==0.13.2 xgboost==3.0.5 -q --user

# %% [markdown]
# <p><strong>Note</strong>: <em>After running the above cell, kindly restart the notebook kernel and run all cells sequentially from the start again.</em></p>

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# To tune model, get different metric scores, and split data
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score,
    ConfusionMatrixDisplay,
)
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, GridSearchCV

# To be used for data scaling and one hot encoding
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

# To impute missing values
from sklearn.impute import SimpleImputer
from sklearn import metrics

# To oversample and undersample data
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# To do hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# To define maximum number of columns to be displayed in a dataframe
pd.set_option("display.max_columns", None)

# To supress scientific notations for a dataframe
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# To help with model building
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
    BaggingClassifier,
)
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

# To suppress scientific notations
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# To supress warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# <h1><strong>Loading the dataset</strong></h1>

# %%
dataset = pd.read_csv("EasyVisa.csv");

# %%
dataset.shape

# %%
df = dataset.copy()

# %% [markdown]
# <h1><strong>Overview of the Dataset</strong></h1>

# %% [markdown]
# <ul>
# <li><p>Observations</p>
# </li>
# <li><p>Sanity checks</p>
# </li>
# </ul>

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %% [markdown]
# <ol>
# <li>Only 3 columns are numerical, rest 9 are object type</li>
# <li>There are no missing values</li>
# </ol>

# %%
df.duplicated().sum()

# %%
df.describe().T

# %%
df.drop(["case_id"], axis=1, inplace=True)

# %%
data = df.copy()

# %% [markdown]
# <h1><a><strong>Exploratory Data Analysis (EDA)</strong></a></h1>

# %% [markdown]
# <ul>
# <li>EDA is an important part of any project involving data.</li>
# <li>It is important to investigate and understand the data better before building a model with it.</li>
# <li>A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.</li>
# <li>A thorough analysis of the data, in addition to the questions mentioned below, should be done.</li>
# </ul>

# %% [markdown]
# <p><strong>Leading Questions</strong></p>
# <p>What is the distribution of visa case statuses (certified vs. denied)?</p>
# <ol>
# <li>What is the distribution of visa case statuses (certified vs. denied)?</li>
# <li>How does the education level of employees impact visa approval rates?</li>
# <li>Is there a significant difference in visa approval rates between employees with and without prior job experience?</li>
# <li>How does the prevailing wage affect visa approval? Do higher wages lead to higher chances of approval?</li>
# <li>Do certain regions in the US have higher visa approval rates compared to others?</li>
# <li>How does the number of employees in a company influence visa approval? Do larger companies have a higher approval rate?</li>
# <li>Are visa approval rates different across various continents of employees? Which continent has the highest and lowest approval rates?</li>
# </ol>

# %% [markdown]
# <h2>Plots</h2>

# %%
# function to plot a boxplot and a histogram along the same scale.

def histogram_boxplot(data, feature, figsize=(15, 10), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=True, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=True, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
### Function to plot distributions

def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(17, 12))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
# function to create labeled barplots

def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
# function to plot stacked bar chart

def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %% [markdown]
# <h2>Univariate Analysis</h2>

# %%
data.info()

# %%
histogram_boxplot(data, "no_of_employees")

# %% [markdown]
# <p>Number of employees tend to be highly right skewed with most distribution less than 100k</p>

# %%
histogram_boxplot(data, "yr_of_estab")

# %% [markdown]
# <p>Most of the companies seem to be estalbished more recently around 2000 and more . The distribution seems to be heavily left skweded.</p>

# %%
histogram_boxplot(data, "prevailing_wage")

# %% [markdown]
# <ol>
# <li>The histogram indicates that the prevailing wage is right skewed, meaning a large number of applicants have lower prevailing wages, and fewer applicants have higher prevailing wages. There's a peak around the lower wage values.</li>
# <li>The average prevailing wage is higher than the median prevailing wage, pulled up by the higher values.</li>
# <li>The boxplot shows several data points extending far to the right, indicating the presence of outliers with very high prevailing wages compared to the majority of the data.</li>
# </ol>

# %%
labeled_barplot(data, "continent")

# %% [markdown]
# <p>Most applications have seem to come from Asia</p>

# %%
labeled_barplot(data, "education_of_employee")

# %% [markdown]
# <p>The highest count of visa is with Bachelors education followed very closely by Masters.</p>

# %%
labeled_barplot(data, "has_job_experience")

# %% [markdown]
# <p>Most applicants seem to have had job experince prior.</p>

# %%
data.info()

# %%
labeled_barplot(data, "requires_job_training")

# %% [markdown]
# <p>Most of the visa applicants dont seem to need job training.</p>

# %%
labeled_barplot(data, "region_of_employment")

# %% [markdown]
# <p>Intended region of employment is very similar in NorthEast South and West regions and compartively low in Midwest and Island</p>

# %%
labeled_barplot(data, "unit_of_wage")

# %% [markdown]
# <p>Most of applications seem to have yearly wages.</p>

# %%
labeled_barplot(data, "full_time_position")

# %% [markdown]
# <p>So its clear that most applicants are full time .</p>

# %%
labeled_barplot(data, "case_status")

# %% [markdown]
# <h2>Bi variate Analysis</h2>

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(data.corr(numeric_only = True), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
data.info()

# %%
distribution_plot_wrt_target(data, "no_of_employees", "case_status")

# %% [markdown]
# <ol>
# <li>Both Certified and Denied visa applications are from companies with lower employee count.</li>
# <li>The boxplot, excluding outliers, provides a clearer view. It shows that the median number of employees for certified cases is slightly higher than for denied cases, but both are quite similar. The interquartile range is also comparable for both 'Certified' and 'Denied' statuses. This suggests that while there are very large companies applying, the majority of applications (both certified and denied) come from companies with a relatively small number of employees (up to around 3000-3500 employees, based on the box height).</li>
# </ol>

# %%
distribution_plot_wrt_target(data, "yr_of_estab", "case_status")

# %% [markdown]
# <p>The year of establishment does not appear to be a strong distinguishing factor between certified and denied visa applications, as both outcomes predominantly occur for companies founded in more recent decades.</p>

# %%
distribution_plot_wrt_target(data, "prevailing_wage", "case_status")

# %% [markdown]
# <ol>
# <li>The first histogram shows the distribution of 'prevailing_wage' for visa applications that were Denied is heavily right-skewed, with a very prominent peak at the lowest wage values (close to 0). This suggests that a large number of denied applications are associated with relatively low prevailing wages.</li>
# <li>While histogram of 'Certified' also is right-skewed, the peak is less sharp and shifted slightly to higher wage values compared to the denied cases. There's a broader distribution of certified cases across a wider range of wages, with a notable concentration in the 50,000-100,000 range, and still a peak at the very low end.</li>
# <li>The box plot shows that the median prevailing wage for certified cases is marginally higher than for denied cases. The interquartile range for certified cases also appears slightly higher and extends further, suggesting that while low wages are present in both, certified visas tend to be associated with slightly higher prevailing wages, or at least a greater proportion of applicants within higher wage brackets get certified compared to denied ones.</li>
# </ol>

# %%
stacked_barplot(df, "continent", "case_status")

# %% [markdown]
# <ol>
# <li>Asia has the highest number of both Certified and Denied applications, reflecting its high volume of overall applications.</li>
# <li>Europe has a very high certification rate, reinforcing its high proportional approval rate shown in the bar chart.</li>
# <li>Africa also shows a strong certification trend proportionally.</li>
# </ol>

# %%
data.info()

# %%
stacked_barplot(data, "education_of_employee", "case_status")

# %% [markdown]
# <p>Most denied applications seems to be high schoolers and Doctorate degree holders have the highest proportion of Certified visas, with a very small orange 'Denied' segment. This indicates a significantly higher approval rate for applicants with a Doctorate.
# Master's degree holders also show a high proportion of Certified visas, second only to Doctorates.
# Bachelor's degree holders have a good proportion of Certified visas, but the orange 'Denied' segment is more noticeable compared to Master's and Doctorates.</p>

# %%
stacked_barplot(data, "has_job_experience", "case_status")

# %% [markdown]
# <p>Applicants with Job experience have lesser denials and more certified than applications with no prior job experience.</p>

# %%
stacked_barplot(data, "requires_job_training", "case_status")

# %% [markdown]
# <p>whether an applicant requires job training or not seems to have a negligible impact on their visa certification rate. The proportion of certified versus denied cases is almost identical for both groups.</p>

# %%
stacked_barplot(data, "region_of_employment", "case_status")

# %% [markdown]
# <ol>
# <li>The Midwest region shows the highest proportion of Certified visas, with the blue 'Certified' segment being significantly larger than the orange 'Denied' segment. This indicates a higher approval rate for applications intended for the Midwest.</li>
# <li>Northeast, West, and Island regions show a slightly lower proportion of Certified visas compared to Midwest and South, implying proportionally higher denial rates.</li>
# <li>North east has highest certified and denied as well indicating they have larger number of applications.</li>
# </ol>

# %%
stacked_barplot(data, "unit_of_wage", "case_status")

# %% [markdown]
# <p>Yearly wage employees despite having most number in yearly show that they have least amount of denials while hourly employees have signifcantly higher denials.</p>

# %%
stacked_barplot(data, "full_time_position", "case_status")

# %% [markdown]
# <p>Whether a position is full-time or part-time appears to have a minimal difference in the proportion of certified versus denied visa applications. Both types of positions show a similar approval rate, with part-time positions having a slightly, but not significantly, higher approval rate.</p>

# %% [markdown]
# <h1><strong>Data Pre-processing</strong></h1>

# %% [markdown]
# <ul>
# <li>Missing value treatment (if needed)</li>
# <li>Feature engineering (if needed)</li>
# <li>Outlier detection and treatment (if needed)</li>
# <li>Preparing data for modeling</li>
# <li>Any other preprocessing steps (if needed)</li>
# </ul>

# %% [markdown]
# <h2>Feature Engineering</h2>

# %%
# Start by creating a fresh copy of the DataFrame to ensure original columns are present
data = df.copy()

# Map 'case_status' to numerical values (0 for Denied, 1 for Certified)
data['case_status'] = data['case_status'].map({'Denied': 0, 'Certified': 1})

# Map 'education_of_employee' to numerical ordinal values based on observed unique values
education_mapping = {
    'High School': 0,
    'Bachelor\'s': 1,
    'Master\'s': 2,
    'Doctorate': 3
}

# Check for any unmapped categories (should not happen with correct mapping, but good practice)
for edu in data['education_of_employee'].unique():
    if edu not in education_mapping:
        print(f"Warning: '{edu}' not found in education_mapping. Please update mapping if needed.")

data['education_of_employee'] = data['education_of_employee'].map(education_mapping)

# Identify columns to one-hot encode
categorical_cols_for_ohe = [
    'continent',
    'has_job_experience',
    'requires_job_training',
    'region_of_employment',
    'full_time_position',
    'unit_of_wage' # Add unit_of_wage to be one-hot encoded
]

# Apply one-hot encoding using pd.get_dummies
data = pd.get_dummies(data, columns=categorical_cols_for_ohe, drop_first=True)

display(data.head())

# %% [markdown]
# <h2>Handle outliers</h2>

# %%
# Apply log transformation to skewed numerical features
# np.log1p is used because it handles zero values gracefully (log(1+x))
data['no_of_employees'] = np.log1p(data['no_of_employees'])
data['prevailing_wage'] = np.log1p(data['prevailing_wage'])

display(data.head())

# %% [markdown]
# <h2>Preparing data for modeling</h2>

# %%
X = data.drop(["case_status"], axis=1)
y = data["case_status"]

# %%
# Splitting data into training, validation and test set:
# first we split data into 2 parts, say temporary and test

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1, stratify=y
)

# then we split the temporary set into train and validation

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, random_state=1, stratify=y_temp
)
print(X_train.shape, X_val.shape, X_test.shape)

# %%
print("Number of rows in train data =", X_train.shape[0])
print("Number of rows in validation data =", X_val.shape[0])
print("Number of rows in test data =", X_test.shape[0])

# %%
data.isnull().sum()

# %%
imputer = SimpleImputer(strategy='mean')
# Reshape the Series to a 2D array before passing to imputer
X_train['no_of_employees'] = imputer.fit_transform(X_train[['no_of_employees']])
X_val['no_of_employees'] = imputer.transform(X_val[['no_of_employees']])
X_test['no_of_employees'] = imputer.transform(X_test[['no_of_employees']])

print("\nMissing values in X_train after imputation:", X_train.isnull().sum().sum())
print("Missing values in X_val after imputation:", X_val.isnull().sum().sum())
print("Missing values in X_test after imputation:", X_test.isnull().sum().sum())

# %% [markdown]
# <h1><strong>Model Building</strong></h1>

# %% [markdown]
# <h2>Perfomance Metrics</h2>

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred, average='weighted')  # to compute F1-score with weighted average

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1": f1,},
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# <h2>Initial Model</h2>

# %%
models = []  # Empty list to store all the models

# Appending models into the list
models.append(("Bagging", BaggingClassifier(estimator=DecisionTreeClassifier(random_state=1, class_weight='balanced'), random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1, class_weight='balanced')))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("XGBoost", XGBClassifier(random_state=1)))

models.append(("dtree", DecisionTreeClassifier(random_state=1, class_weight='balanced')))

print("\nTraining Performance:\n")
for name, model in models:
    model.fit(X_train, y_train)
    scores = recall_score(y_train, model.predict(X_train))
    print("{}: {}".format(name, scores))

print("\nValidation Performance:\n")
for name, model in models:
    model.fit(X_train, y_train)
    scores_val = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores_val))

# %%
print("\nTraining and Validation Performance Difference:\n")

for name, model in models:
    model.fit(X_train, y_train)
    scores_train = recall_score(y_train, model.predict(X_train))
    scores_val = recall_score(y_val, model.predict(X_val))
    difference1 = scores_train - scores_val
    print("{}: Training Score: {:.4f}, Validation Score: {:.4f}, Difference: {:.4f}".format(name, scores_train, scores_val, difference1))

# %% [markdown]
# <h1><strong>Model Performance Improvement</strong></h1>

# %% [markdown]
# <h2><strong>Note</strong></h2>

# %% [markdown]
# <ol>
# <li>Sample parameter grids have been provided to do necessary hyperparameter tuning. These sample grids are expected to provide a balance between model performance improvement and execution time. One can extend/reduce the parameter grid based on execution time and system configuration.</li>
# </ol>
# <ul>
# <li>Please note that if the parameter grid is extended to improve the model performance further, the execution time will increase</li>
# </ul>
# <ol>
# <li>The models chosen in this notebook are based on test runs. One can update the best models as obtained upon code execution and tune them for best performance.</li>
# </ol>
# <ul>
# <li>For Gradient Boosting:</li>
# </ul>
# <pre><code>param_grid = {
#     "init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
#     "n_estimators": np.arange(50,110,25),
#     "learning_rate": [0.01,0.1,0.05],
#     "subsample":[0.7,0.9],
#     "max_features":[0.5,0.7,1],
# }
# </code></pre>
# <ul>
# <li>For Adaboost:</li>
# </ul>
# <pre><code>param_grid = {
#     "n_estimators": np.arange(50,110,25),
#     "learning_rate": [0.01,0.1,0.05],
#     "base_estimator": [
#         DecisionTreeClassifier(max_depth=2, random_state=1),
#         DecisionTreeClassifier(max_depth=3, random_state=1),
#     ],
# }
# </code></pre>
# <ul>
# <li>For Bagging Classifier:</li>
# </ul>
# <pre><code>param_grid = {
#     'max_samples': [0.8,0.9,1],
#     'max_features': [0.7,0.8,0.9],
#     'n_estimators' : [30,50,70],
# }
# </code></pre>
# <ul>
# <li>For Random Forest:</li>
# </ul>
# <pre><code>param_grid = {
#     "n_estimators": [50,110,25],
#     "min_samples_leaf": np.arange(1, 4),
#     "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
#     "max_samples": np.arange(0.4, 0.7, 0.1)
# }
# </code></pre>
# <ul>
# <li>For Decision Trees:</li>
# </ul>
# <pre><code>param_grid = {
#     'max_depth': np.arange(2,6),
#     'min_samples_leaf': [1, 4, 7],
#     'max_leaf_nodes' : [10, 15],
#     'min_impurity_decrease': [0.0001,0.001]
# }
# </code></pre>
# <ul>
# <li>For XGBoost:</li>
# </ul>
# <pre><code>param_grid={'n_estimators':np.arange(50,110,25),
#             'scale_pos_weight':[1,2,5],
#             'learning_rate':[0.01,0.1,0.05],
#             'gamma':[1,3],
#             'subsample':[0.7,0.9]
# }
# </code></pre>

# %% [markdown]
# <h2>Over Sampling</h2>

# %%
print("Before Oversampling, counts of label 'Certified': {}".format(sum(y_train == 1)))
print("Before Oversampling, counts of label 'Denied': {} \n".format(sum(y_train == 0)))

sm = SMOTE(
    sampling_strategy=1, k_neighbors=5, random_state=1
)  # Synthetic Minority Over Sampling Technique
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)

print("After Oversampling, counts of label 'Certified': {}".format(sum(y_train_over == 1)))
print("After Oversampling, counts of label 'Denied': {} \n".format(sum(y_train_over == 0)))

print("After Oversampling, the shape of train_X: {}".format(X_train_over.shape))
print("After Oversampling, the shape of train_y: {} \n".format(y_train_over.shape))

# %%
models = []  # Empty list to store all the models

# Appending models into the list
models.append(("Bagging", BaggingClassifier(estimator=DecisionTreeClassifier(random_state=1, class_weight='balanced'), random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1, class_weight='balanced')))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("XGBoost", XGBClassifier(random_state=1))) # Added XGBoost
models.append(("dtree", DecisionTreeClassifier(random_state=1, class_weight='balanced')))

print("\n" "Training Performance:" "\n")
for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores = recall_score(y_train_over, model.predict(X_train_over))
    print("{}: {}".format(name, scores))

print("\n" "Validation Performance:" "\n")

for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))

print("\nTraining and Validation Performance Difference:\n")

for name, model in models:
    model.fit(X_train_over, y_train_over)
    scores_train = recall_score(y_train_over, model.predict(X_train_over))
    scores_val = recall_score(y_val, model.predict(X_val))
    difference2 = scores_train - scores_val
    print("{}: Training Score: {:.4f}, Validation Score: {:.4f}, Difference: {:.4f}".format(name, scores_train, scores_val, difference2))

# %% [markdown]
# <h2>UnderSampling</h2>

# %%
print("Before Undersampling, counts of label 'Certified': {}".format(sum(y_train == 1)))
print("Before Undersampling, counts of label 'Denied': {} \n".format(sum(y_train == 0)))

rus = RandomUnderSampler(sampling_strategy=1, random_state=1)
X_train_under, y_train_under = rus.fit_resample(X_train, y_train)

print("After Undersampling, counts of label 'Certified': {}".format(sum(y_train_under == 1)))
print("After Undersampling, counts of label 'Denied': {} \n".format(sum(y_train_under == 0)))

print("After Undersampling, the shape of train_X: {}".format(X_train_under.shape))
print("After Undersampling, the shape of train_y: {} \n".format(y_train_under.shape))

models = []  # Empty list to store all the models

# Appending models into the list
models.append(("Bagging", BaggingClassifier(estimator=DecisionTreeClassifier(random_state=1, class_weight='balanced'), random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1, class_weight='balanced')))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("XGBoost", XGBClassifier(random_state=1))) # Added XGBoost
models.append(("dtree", DecisionTreeClassifier(random_state=1, class_weight='balanced')))

print("\n" "Training Performance (Undersampled):" "\n")
for name, model in models:
    model.fit(X_train_under, y_train_under)
    scores = recall_score(y_train_under, model.predict(X_train_under))
    print("{}: {}".format(name, scores))

print("\n" "Validation Performance (Undersampled):" "\n")

for name, model in models:
    model.fit(X_train_under, y_train_under)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))

print("\nTraining and Validation Performance Difference (Undersampled):\n")

for name, model in models:
    model.fit(X_train_under, y_train_under)
    scores_train = recall_score(y_train_under, model.predict(X_train_under))
    scores_val = recall_score(y_val, model.predict(X_val))
    difference = scores_train - scores_val
    print("{}: Training Score: {:.4f}, Validation Score: {:.4f}, Difference: {:.4f}".format(name, scores_train, scores_val, difference))

# %% [markdown]
# <h1><strong>Hyperparameter Tuning</strong></h1>

# %% [markdown]
# <h2>Tuning AdaBoost</h2>

# %% [markdown]
# <h3>with oversampled data and random search</h3>

# %%
# defining model
Model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50, 110, 25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "estimator": [
        DecisionTreeClassifier(max_depth=1, random_state=1),
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_adb_randomcv = AdaBoostClassifier(
    random_state=1,
    n_estimators=100,
    learning_rate=1,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1),
)
tuned_adb_randomcv.fit(X_train_over, y_train_over)

# Checking model's performance on training set
adb_train_randomcv = model_performance_classification_sklearn(tuned_adb_randomcv, X_train_over, y_train_over)
adb_train_randomcv
display(adb_train_randomcv)

# Checking model's performance on validation set
adb_val_randomcv = model_performance_classification_sklearn(tuned_adb_randomcv, X_val, y_val)
adb_val_randomcv
display(adb_val_randomcv)

# %% [markdown]
# <h3>with original data</h3>

# %%
# defining model
Model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50, 110, 25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "estimator": [
        DecisionTreeClassifier(max_depth=1, random_state=1),
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
grid_search_cv = GridSearchCV(estimator=Model, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
grid_search_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(grid_search_cv.best_params_,grid_search_cv.best_score_))

# %%
tuned_adb_gridcv = AdaBoostClassifier(
    random_state=1,
    n_estimators=100,
    learning_rate=0.1,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1),
)
tuned_adb_gridcv.fit(X_train, y_train)

# Checking model's performance on training set
adb_train_gridcv = model_performance_classification_sklearn(tuned_adb_gridcv, X_train, y_train)
display(adb_train_gridcv)

# Checking model's performance on validation set
adb_val_gridcv = model_performance_classification_sklearn(tuned_adb_gridcv, X_val, y_val)
display(adb_val_gridcv)

# %% [markdown]
# <h3>with undersampled data</h3>

# %%
# defining model
Model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": np.arange(50, 110, 25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "estimator": [
        DecisionTreeClassifier(max_depth=1, random_state=1),
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_under, y_train_under)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_adb_randomcv_undersampled = AdaBoostClassifier(
    random_state=1,
    n_estimators=75,
    learning_rate=0.2,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1),
)
tuned_adb_randomcv_undersampled.fit(X_train_over, y_train_over)

# Checking model's performance on training set
adb_train_randomcv_undersampled = model_performance_classification_sklearn(tuned_adb_randomcv_undersampled, X_train_under, y_train_under)
adb_train_randomcv_undersampled
display(adb_train_randomcv_undersampled)

# Checking model's performance on validation set
adb_val_randomcv_undersampled = model_performance_classification_sklearn(tuned_adb_randomcv_undersampled, X_val, y_val)
adb_val_randomcv_undersampled
display(adb_val_randomcv_undersampled)

# %% [markdown]
# <h2>Tuning  Gradient Boosting model</h2>

# %% [markdown]
# <h3>Tuning GBM with OverSampled Data</h3>

# %%
#defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
    "n_estimators": np.arange(75,150,25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "subsample":[0.5,0.7,1],
    "max_features":[0.5,0.7,1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_gbm = GradientBoostingClassifier(
    random_state=1,
    subsample=0.7,
    n_estimators=125,
    max_features=0.7,
    learning_rate=0.2,
    init=DecisionTreeClassifier(random_state=1),
)
tuned_gbm.fit(X_train_over, y_train_over)

# Checking model's performance on training set
gbm_train = model_performance_classification_sklearn(tuned_gbm, X_train_over, y_train_over)
display(gbm_train)

gbm_val = model_performance_classification_sklearn(tuned_gbm, X_val, y_val)
display(gbm_val)

# %% [markdown]
# <h3>with original data</h3>

# %%
#defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
    "n_estimators": np.arange(75,150,25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "subsample":[0.5,0.7,1],
    "max_features":[0.5,0.7,1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_gbm_originaldata = GradientBoostingClassifier(
    random_state=1,
    subsample=0.7,
    n_estimators=125,
    max_features=0.5,
    learning_rate=0.05,
    init=DecisionTreeClassifier(random_state=1),
)
tuned_gbm_originaldata.fit(X_train, y_train)

# Checking model's performance on training set
gbm_train_original = model_performance_classification_sklearn(tuned_gbm_originaldata, X_train, y_train)
display(gbm_train_original)

gbm_val_original = model_performance_classification_sklearn(tuned_gbm_originaldata, X_val, y_val)
display(gbm_val_original)

# %% [markdown]
# <h3>with under sampled data</h3>

# %%
#defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid = {
    "init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
    "n_estimators": np.arange(75,150,25),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "subsample":[0.5,0.7,1],
    "max_features":[0.5,0.7,1],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_under, y_train_under)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_gbm_undersampled = GradientBoostingClassifier(
    random_state=1,
    subsample=0.5,
    n_estimators=100,
    max_features=0.7,
    learning_rate=0.05,
    init=DecisionTreeClassifier(random_state=1),
)
tuned_gbm_undersampled.fit(X_train, y_train)

# Checking model's performance on training set
gbm_train_undersampled = model_performance_classification_sklearn(tuned_gbm_undersampled, X_train_under, y_train_under)
display(gbm_train_undersampled)

gbm_val_undersampled = model_performance_classification_sklearn(tuned_gbm_undersampled, X_val, y_val)
display(gbm_val_undersampled)

# %% [markdown]
# <h2>Tuning XgBoost</h2>

# %% [markdown]
# <h3>with oversampled data</h3>

# %%
Model = XGBClassifier(random_state=1, eval_metric='logloss')

param_grid={'n_estimators':np.arange(50,110,25),
            'scale_pos_weight':[1,2,5],
            'learning_rate':[0.01,0.1,0.05],
            'gamma':[1,3],
            'subsample':[0.7,0.9]
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
# Using the best parameters to build the final XGBoost model
tuned_xgb = XGBClassifier(
    random_state=1,
    subsample=0.9,
    scale_pos_weight=1,
    n_estimators=100,
    learning_rate=0.1,
    gamma=1
)

tuned_xgb.fit(X_train_over, y_train_over)
# Checking model's performance on training set
xgb_train = model_performance_classification_sklearn(tuned_xgb, X_train_over, y_train_over)
display(xgb_train)

# Checking model's performance on validation set
xgb_val = model_performance_classification_sklearn(tuned_xgb, X_val, y_val)
display(xgb_val)

# %% [markdown]
# <h3>with original data</h3>

# %%
Model = XGBClassifier(random_state=1, eval_metric='logloss')

param_grid={'n_estimators':np.arange(50,110,25),
            'scale_pos_weight':[1,2,5],
            'learning_rate':[0.01,0.1,0.05],
            'gamma':[1,3],
            'subsample':[0.7,0.9]
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
# Using the best parameters to build the final XGBoost model
tuned_xgb_original = XGBClassifier(
    random_state=1,
    subsample=0.9,
    scale_pos_weight=1,
    n_estimators=75,
    learning_rate=0.05,
    gamma=3
)

tuned_xgb_original.fit(X_train, y_train)

# Checking model's performance on training set
xgb_train_original = model_performance_classification_sklearn(tuned_xgb_original, X_train, y_train)
display(xgb_train_original)

# Checking model's performance on validation set
xgb_val_original = model_performance_classification_sklearn(tuned_xgb_original, X_val, y_val)
display(xgb_val_original)

# %% [markdown]
# <h2>Tuning Bagging Classifier with oversample data</h2>

# %%
Model = BaggingClassifier(random_state=1)

param_grid = {
    'max_samples': [0.8,0.9,1],
    'max_features': [0.7,0.8,0.9],
    'n_estimators' : [30,50,70],
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_bagging = BaggingClassifier(
    random_state=1,
    max_samples=0.9,
    max_features=0.8,
    n_estimators=70
)

tuned_bagging.fit(X_train_over, y_train_over)

# Checking model's performance on training set
bagging_train = model_performance_classification_sklearn(tuned_bagging, X_train_over, y_train_over)
display(bagging_train)

# Checking model's performance on validation set
bagging_val = model_performance_classification_sklearn(tuned_bagging, X_val, y_val)
display(bagging_val)

# %% [markdown]
# <h3>with original data</h3>

# %%
Model = BaggingClassifier(random_state=1)

param_grid = {
    'max_samples': [0.8,0.9,1],
    'max_features': [0.7,0.8,0.9],
    'n_estimators' : [30,50,70],
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_bagging_original = BaggingClassifier(
    random_state=1,
    max_samples=0.8,
    max_features=0.9,
    n_estimators=70
)

tuned_bagging_original.fit(X_train, y_train)

# Checking model's performance on training set
bagging_train_original = model_performance_classification_sklearn(tuned_bagging_original, X_train, y_train)
display(bagging_train_original)

# Checking model's performance on validation set
bagging_val_original = model_performance_classification_sklearn(tuned_bagging_original, X_val, y_val)
display(bagging_val_original)

# %% [markdown]
# <h2>Tuning Decision Trees with Oversampled Data</h2>

# %%
Model = DecisionTreeClassifier(random_state=1)

param_grid = {
    'max_depth': np.arange(2,6),
    'min_samples_leaf': [1, 4, 7],
    'max_leaf_nodes' : [10, 15],
    'min_impurity_decrease': [0.0001,0.001]
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1, n_jobs = -1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

# %%
tuned_dt = DecisionTreeClassifier(
    min_samples_leaf=1,
    min_impurity_decrease=0.0001,
    max_leaf_nodes=15,
    max_depth=5,
)

tuned_dt.fit(X_train_over, y_train_over)

# %%
dt_train = model_performance_classification_sklearn(tuned_dt, X_train_over, y_train_over)
dt_train

# %%
# Checking model's performance on validation set
dt_val = model_performance_classification_sklearn(tuned_dt, X_val, y_val)
dt_val

# %% [markdown]
# <h3>Tuning DecisionTree with GridSearchCV</h3>

# %%
Model = DecisionTreeClassifier(random_state=1)

param_grid = {
    'max_depth': np.arange(2,6),
    'min_samples_leaf': [1, 4, 7],
    'max_leaf_nodes' : [10, 15],
    'min_impurity_decrease': [0.0001,0.001]
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling GridSearchCV
grid_search_cv_original = GridSearchCV(estimator=Model, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)

#Fitting parameters in GridSearchCV
grid_search_cv_original.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(grid_search_cv_original.best_params_,grid_search_cv_original.best_score_))

# %%
tuned_dt_original = DecisionTreeClassifier(
    min_samples_leaf=1,
    min_impurity_decrease=0.0001,
    max_leaf_nodes=15,
    max_depth=5,
)

tuned_dt_original.fit(X_train, y_train)

dt_train = model_performance_classification_sklearn(tuned_dt_original, X_train, y_train)
display(dt_train)

# Checking model's performance on validation set
dt_val = model_performance_classification_sklearn(tuned_dt_original, X_val, y_val)
display(dt_val)

# %% [markdown]
# <h2>Tuning RandomForest with over sampled data</h2>

# %%
Model = RandomForestClassifier(random_state=1)

param_grid = {
    "n_estimators": [50,110,25],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
    "max_samples": np.arange(0.4, 0.7, 0.1)
}
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score, average='weighted')

#Calling GridSearchCV
grid_search_cv = GridSearchCV(estimator=Model, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)

#Fitting parameters in GridSearchCV
grid_search_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(grid_search_cv.best_params_,grid_search_cv.best_score_))

# %%
tuned_rf_with_randomcv = RandomForestClassifier(
    n_estimators=110,
    min_samples_leaf=1,
    max_samples=0.5,
    max_features='sqrt',
)

tuned_rf_with_randomcv.fit(X_train_over, y_train_over)

# %%
rf_train = model_performance_classification_sklearn(tuned_rf_with_randomcv, X_train_over, y_train_over)
display(rf_train)

# %%
# Checking model's performance on validation set
rf_val = model_performance_classification_sklearn(tuned_rf_with_randomcv, X_val, y_val)
display(rf_val)

# %% [markdown]
# <h1><strong>Model Comparison and Final Model Selection</strong></h1>

# %% [markdown]
# <h3><strong>Model Comparison</strong></h3><p>Let's compare the performance metrics of all the models we've trained and tuned, focusing on recall, accuracy, precision, and F1-score to select the best model.</p>

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
      adb_train_gridcv.T,
      adb_train_randomcv.T,
      adb_train_randomcv_undersampled.T,
      gbm_train.T,
      gbm_train_original.T,
      gbm_train_undersampled.T,
      xgb_train.T,
      xgb_train_original.T,
      bagging_train.T,
      bagging_train_original.T,
      dt_train.T,
      rf_train.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "AdaBoost trained with Oversampled data with gridcv",
    "AdaBoost trained with Oversampled data with randomcv",
    "AdaBoost trained with Undersampled data",
    "Gradient boosting trained with Oversampled data",
    "Gradient Boosting trained with original data",
    "Gradient Boosting trained with Undersampled data",
    "XGBoost trained with Oversampled data",
    "XGBoost trained with original data",
    "Bagging Classifier trained with Oversampled data",
    "Bagging Classifier trained with Oversample data with training data",
    "Decsion Tree trained with Oversampled data",
    "RandomForest trained with Undersampled data",
]
print("Training performance comparison:")
models_train_comp_df

# %%
models_val_comp_df = pd.concat(
    [
    adb_val_gridcv.T,
    adb_val_randomcv.T,
    adb_val_randomcv_undersampled.T,
    gbm_val.T,
    gbm_val_original.T,
    gbm_val_undersampled.T,
    xgb_val.T,
    xgb_val_original.T,
      bagging_val.T,
    bagging_val_original.T,
    dt_val.T,
    rf_val.T,
    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Tuned AdaBoost (GridSearchCV on Oversampled Data)",
    "Tuned AdaBoost (RandomizedSearchCV on Oversampled Data)",
    "Tuned AdaBoost (RandomizedSearchCV on Undersampled Data)",
    "Tuned Gradient Boosting (Oversampled Data)",
    "Tuned Gradient Boosting (Original Data)",
    "Tuned Gradient Boosting (Undersampled Data)",
    "Tuned XGBoost (Oversampled Data)",
    "Tuned XGBoost (Original Data)",
    "Tuned Bagging (Oversampled Data)",
    "Tuned Bagging (Original Data)",
    "Tuned Decision Tree (Oversampled Data)",
    "Tuned RandomForest (Oversampled Data)",
]
print("Validation performance comparison:")
models_val_comp_df

# %% [markdown]
# <p>Among these  models, I would recommend the Tuned XGBoost (Original Data). with training recall and f1 of 0.885 and 0.759 on training set and validation recall with 0.869 and a good F1 score of 0.736</p>

# %%
xgb_test_original = model_performance_classification_sklearn(tuned_xgb_original, X_test, y_test)
display(xgb_test_original)

adb_test_gridcv = model_performance_classification_sklearn(tuned_adb_gridcv, X_test, y_test)
display(adb_test_gridcv)

xgb_test_oversampled = model_performance_classification_sklearn(tuned_xgb, X_test, y_test)
display(xgb_test_oversampled)

bagging_test_original = model_performance_classification_sklearn(tuned_bagging_original, X_test, y_test)
display(bagging_test_original)

# %%
models_test_comp_df = pd.concat(
    [
        adb_test_gridcv.T,
        xgb_test_oversampled.T,
        xgb_test_original.T,
        bagging_test_original.T,
    ],
    axis=1,
)
models_test_comp_df.columns = [
    "Tuned AdaBoost (GridSearchCV on Original Data)",
    "Tuned XGBoost (Oversampled Data)",
    "Tuned XGBoost (Original Data)",
    "Tuned Bagging (Original Data)",
]
print("Test performance comparison:")
display(models_test_comp_df)

# %% [markdown]
# <p>Final Pick: Tuned XGBoost (Original Data)</p>

# %% [markdown]
# <h1><strong>Key Features</strong></h1>

# %%
# Analyze feature importances for the Tuned XGBoost Model (Original Data)
print('\nFeature Importances for Tuned XGBoost Model (Original Data):')
feature_importances_original_xgb = pd.Series(tuned_xgb_original.feature_importances_, index=X_train.columns).sort_values(ascending=False)
display(feature_importances_original_xgb)

plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importances_original_xgb.values, y=feature_importances_original_xgb.index)
plt.xticks(rotation=0)
plt.title('Feature Importances for Tuned XGBoost Model (Original Data)')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %% [markdown]
# <h1><strong>Actionable Insights and Recommendations</strong></h1>

# %% [markdown]
# <p>Our chosen model, the Tuned XGBoost (Original Data), demonstrated the best overall performance on the independent test set with an F1-score of 0.724, an Accuracy of 0.736, a Recall of 0.868, and a Precision of 0.767.</p>
# <p><strong>Recommendations and Insights</strong>:</p>
# <ol>
# <li>Prioritize Highly Educated and Experienced Applicants:</li>
# </ol>
# <p>EasyVisa should actively seek and prioritize applicants with higher education levels (Master's and Doctorate degrees) and strong, documented job experience. These candidates have the highest likelihood of visa certification.</p>
# <ol>
# <li>Strategic Guidance on Prevailing Wage:</li>
# </ol>
# <p>While 'prevailing_wage' is a factor, its direct importance is lower than education and experience. EasyVisa should ensure that the proposed wage meets or slightly exceeds the prevailing wage to avoid denial flags, but emphasize that it's not the sole determinant for approval.</p>
# <ol>
# <li>Leverage Geographical Insights:</li>
# </ol>
# <p>Applicants from Europe and those targeting the Midwest region for employment show higher approval rates. This could indicate specific industry needs or policy alignment.</p>
# <ol>
# <li>Focus on 'Yearly Wages':
# The model indicates 'unit_of_wage_Year' has a significant influence. Yearly wage positions are generally preferred.</li>
# </ol>
